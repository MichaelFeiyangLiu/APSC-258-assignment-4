# %%
#P1

import numpy as np
import math as mt
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt
import random

x=np.linspace(-2*mt.pi,2*mt.pi,1000)
ya=(np.sin(x))*x**2+2*np.sin(x)
z=np.random.randn(1,1000)
y=ya+z
X_data=np.reshape(x,[1000,1])
y_data=np.reshape(y,[1000,1])
from keras.models import Sequential
from keras.layers import Dense
mymodel = Sequential()
# input and Hidden layer-1 
mymodel.add(Dense(units=50, input_dim=1,
kernel_initializer='normal',activation='relu'))
# Hidden layer-2
mymodel.add(Dense(units=50,
kernel_initializer='normal',activation='relu'))
# Hidden layer-3
mymodel.add(Dense(units=50,
kernel_initializer='normal',activation='relu'))
# Hidden layer-4
mymodel.add(Dense(units=50,
kernel_initializer='normal',activation='relu'))


# output layer
mymodel.add(Dense(units=1,kernel_initializer='normal'))
print(mymodel.summary())
from sklearn.model_selection import KFold
sum_mse=0
sum_r_square=0
kf=KFold(n_splits=5)
for train_index, test_index in kf.split(X_data):
    X_train, X_test = X_data[train_index], X_data[test_index]
    y_train, y_test = y_data[train_index], y_data[test_index]
    # Training our model build above
    mymodel.compile(loss='mean_squared_error', optimizer='adam')
    # Training model
    mymodel.fit(X_train, y_train, batch_size = 32, epochs = 50, verbose=0)
    y_pred=mymodel.predict(X_test)
    # MSE calculation base true output and model output
    mse = mean_squared_error(y_test, y_pred)
    # R-square calculation base true output and model output
    r_squared = r2_score(y_test, y_pred)
    # MSE calculation base true output and model output
    mse = mean_squared_error(y_test, y_pred)
    # R-square calculation base true output and model output
    r_squared = r2_score(y_test, y_pred)
    sum_mse=+mse
    sum_r_square=+r_squared
avg_mse=sum_mse/5
avg_r_squared = sum_r_square /5
print(f'mse = {avg_mse:.2}')
print(f'r_squared = {avg_r_squared:.2%}')
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_26 (Dense)            (None, 50)                100
#
#  dense_27 (Dense)            (None, 50)                2550
#
#  dense_28 (Dense)            (None, 50)                2550
#
#  dense_29 (Dense)            (None, 50)                2550
#
#  dense_30 (Dense)            (None, 1)                 51
#
# ...
# Total params: 7,801
# Trainable params: 7,801
# Non-trainable params: 0
# _________________________________________________________________
# None
# mse = 3.8e+01
# r_squared = -62.28%

# %%
#P1

import numpy as np
import math as mt
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt
import random

x=np.linspace(-2*mt.pi,2*mt.pi,1000)
ya=(np.sin(x))*x**2+2*np.sin(x)
z=np.random.randn(1,1000)
y=ya+z
X_data=np.reshape(x,[1000,1])
y_data=np.reshape(y,[1000,1])
from keras.models import Sequential
from keras.layers import Dense
mymodel = Sequential()
# input and Hidden layer-1 
mymodel.add(Dense(units=50, input_dim=1,
kernel_initializer='normal',activation='relu'))
# Hidden layer-2
mymodel.add(Dense(units=50,
kernel_initializer='normal',activation='relu'))
# Hidden layer-3
mymodel.add(Dense(units=50,
kernel_initializer='normal',activation='relu'))
# Hidden layer-4
mymodel.add(Dense(units=50,
kernel_initializer='normal',activation='relu'))
# Hidden layer-5
mymodel.add(Dense(units=50,
kernel_initializer='normal',activation='relu'))
# Hidden layer-6
mymodel.add(Dense(units=50,
kernel_initializer='normal',activation='relu'))

# output layer
mymodel.add(Dense(units=1,kernel_initializer='normal'))
print(mymodel.summary())
from sklearn.model_selection import KFold
sum_mse=0
sum_r_square=0
kf=KFold(n_splits=5)
for train_index, test_index in kf.split(X_data):
    X_train, X_test = X_data[train_index], X_data[test_index]
    y_train, y_test = y_data[train_index], y_data[test_index]
    # Training our model build above
    mymodel.compile(loss='mean_squared_error', optimizer='adam')
    # Training model
    mymodel.fit(X_train, y_train, batch_size = 32, epochs = 50, verbose=0)
    y_pred=mymodel.predict(X_test)
    # MSE calculation base true output and model output
    mse = mean_squared_error(y_test, y_pred)
    # R-square calculation base true output and model output
    r_squared = r2_score(y_test, y_pred)
    # MSE calculation base true output and model output
    mse = mean_squared_error(y_test, y_pred)
    # R-square calculation base true output and model output
    r_squared = r2_score(y_test, y_pred)
    sum_mse=+mse
    sum_r_square=+r_squared
avg_mse=sum_mse/5
avg_r_squared = sum_r_square /5
print(f'mse = {avg_mse:.2}')
print(f'r_squared = {avg_r_squared:.2%}')
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_8 (Dense)             (None, 50)                100
#
#  dense_9 (Dense)             (None, 50)                2550
#
#  dense_10 (Dense)            (None, 50)                2550
#
#  dense_11 (Dense)            (None, 50)                2550
#
#  dense_12 (Dense)            (None, 50)                2550
#
#  dense_13 (Dense)            (None, 50)                2550
#
#  dense_14 (Dense)            (None, 1)                 51
#
# ...
# Total params: 12,901
# Trainable params: 12,901
# Non-trainable params: 0
# _________________________________________________________________
# None
# mse = 4.1e+01
# r_squared = -68.38%

# %%
#P1

import numpy as np
import math as mt
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt
import random

x=np.linspace(-2*mt.pi,2*mt.pi,1000)
ya=(np.sin(x))*x**2+2*np.sin(x)
z=np.random.randn(1,1000)
y=ya+z
X_data=np.reshape(x,[1000,1])
y_data=np.reshape(y,[1000,1])
from keras.models import Sequential
from keras.layers import Dense
mymodel = Sequential()
# input and Hidden layer-1 
mymodel.add(Dense(units=50, input_dim=1,
kernel_initializer='normal',activation='relu'))
# Hidden layer-2
mymodel.add(Dense(units=50,
kernel_initializer='normal',activation='relu'))
# Hidden layer-3
mymodel.add(Dense(units=50,
kernel_initializer='normal',activation='relu'))
# Hidden layer-4
mymodel.add(Dense(units=50,
kernel_initializer='normal',activation='relu'))
# Hidden layer-5
mymodel.add(Dense(units=50,
kernel_initializer='normal',activation='relu'))

# output layer
mymodel.add(Dense(units=1,kernel_initializer='normal'))
print(mymodel.summary())
from sklearn.model_selection import KFold
sum_mse=0
sum_r_square=0
kf=KFold(n_splits=5)
for train_index, test_index in kf.split(X_data):
    X_train, X_test = X_data[train_index], X_data[test_index]
    y_train, y_test = y_data[train_index], y_data[test_index]
    # Training our model build above
    mymodel.compile(loss='mean_squared_error', optimizer='adam')
    # Training model
    mymodel.fit(X_train, y_train, batch_size = 32, epochs = 50, verbose=0)
    y_pred=mymodel.predict(X_test)
    # MSE calculation base true output and model output
    mse = mean_squared_error(y_test, y_pred)
    # R-square calculation base true output and model output
    r_squared = r2_score(y_test, y_pred)
    # MSE calculation base true output and model output
    mse = mean_squared_error(y_test, y_pred)
    # R-square calculation base true output and model output
    r_squared = r2_score(y_test, y_pred)
    sum_mse=+mse
    sum_r_square=+r_squared
avg_mse=sum_mse/5
avg_r_squared = sum_r_square /5
print(f'mse = {avg_mse:.2}')
print(f'r_squared = {avg_r_squared:.2%}')
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_15 (Dense)            (None, 50)                100
#
#  dense_16 (Dense)            (None, 50)                2550
#
#  dense_17 (Dense)            (None, 50)                2550
#
#  dense_18 (Dense)            (None, 50)                2550
#
#  dense_19 (Dense)            (None, 50)                2550
#
#  dense_20 (Dense)            (None, 1)                 51
#
# ...
# Total params: 10,351
# Trainable params: 10,351
# Non-trainable params: 0
# _________________________________________________________________
# None
# mse = 2.8e+01
# r_squared = -42.84%

# %%
#P1

import numpy as np
import math as mt
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt
import random

x=np.linspace(-2*mt.pi,2*mt.pi,1000)
ya=(np.sin(x))*x**2+2*np.sin(x)
z=np.random.randn(1,1000)
y=ya+z
X_data=np.reshape(x,[1000,1])
y_data=np.reshape(y,[1000,1])
from keras.models import Sequential
from keras.layers import Dense
mymodel = Sequential()
# input and Hidden layer-1 
mymodel.add(Dense(units=50, input_dim=1,
kernel_initializer='normal',activation='relu'))
# Hidden layer-2
mymodel.add(Dense(units=50,
kernel_initializer='normal',activation='relu'))
# Hidden layer-3
mymodel.add(Dense(units=50,
kernel_initializer='normal',activation='relu'))
# Hidden layer-4
mymodel.add(Dense(units=50,
kernel_initializer='normal',activation='relu'))
# Hidden layer-5
mymodel.add(Dense(units=50,
kernel_initializer='normal',activation='relu'))
# Hidden layer-6
mymodel.add(Dense(units=50,
kernel_initializer='normal',activation='relu'))
# Hidden layer-7
mymodel.add(Dense(units=50,
kernel_initializer='normal',activation='relu'))

# output layer
mymodel.add(Dense(units=1,kernel_initializer='normal'))
print(mymodel.summary())
from sklearn.model_selection import KFold
sum_mse=0
sum_r_square=0
kf=KFold(n_splits=5)
for train_index, test_index in kf.split(X_data):
    X_train, X_test = X_data[train_index], X_data[test_index]
    y_train, y_test = y_data[train_index], y_data[test_index]
    # Training our model build above
    mymodel.compile(loss='mean_squared_error', optimizer='adam')
    # Training model
    mymodel.fit(X_train, y_train, batch_size = 32, epochs = 50, verbose=0)
    y_pred=mymodel.predict(X_test)
    # MSE calculation base true output and model output
    mse = mean_squared_error(y_test, y_pred)
    # R-square calculation base true output and model output
    r_squared = r2_score(y_test, y_pred)
    # MSE calculation base true output and model output
    mse = mean_squared_error(y_test, y_pred)
    # R-square calculation base true output and model output
    r_squared = r2_score(y_test, y_pred)
    sum_mse=+mse
    sum_r_square=+r_squared
avg_mse=sum_mse/5
avg_r_squared = sum_r_square /5
print(f'mse = {avg_mse:.2}')
print(f'r_squared = {avg_r_squared:.2%}')
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_37 (Dense)            (None, 50)                100
#
#  dense_38 (Dense)            (None, 50)                2550
#
#  dense_39 (Dense)            (None, 50)                2550
#
#  dense_40 (Dense)            (None, 50)                2550
#
#  dense_41 (Dense)            (None, 50)                2550
#
#  dense_42 (Dense)            (None, 50)                2550
#
#  dense_43 (Dense)            (None, 50)                2550
#
#  dense_44 (Dense)            (None, 1)                 51
#
# ...
# Total params: 15,451
# Trainable params: 15,451
# Non-trainable params: 0
# _________________________________________________________________
# None
# mse = 3.8e+01
# r_squared = -61.27%

# %%
#P1

import numpy as np
import math as mt
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt
import random

x=np.linspace(-2*mt.pi,2*mt.pi,1000)
ya=(np.sin(x))*x**2+2*np.sin(x)
z=np.random.randn(1,1000)
y=ya+z
X_data=np.reshape(x,[1000,1])
y_data=np.reshape(y,[1000,1])
from keras.models import Sequential
from keras.layers import Dense
mymodel = Sequential()
# input and Hidden layer-1 
mymodel.add(Dense(units=50, input_dim=1,
kernel_initializer='normal',activation='relu'))
# Hidden layer-2
mymodel.add(Dense(units=50,
kernel_initializer='normal',activation='relu'))
# Hidden layer-3
mymodel.add(Dense(units=50,
kernel_initializer='normal',activation='relu'))
# Hidden layer-4
mymodel.add(Dense(units=50,
kernel_initializer='normal',activation='relu'))
# Hidden layer-5
mymodel.add(Dense(units=50,
kernel_initializer='normal',activation='relu'))
# Hidden layer-6
mymodel.add(Dense(units=50,
kernel_initializer='normal',activation='relu'))
# Hidden layer-7
mymodel.add(Dense(units=50,
kernel_initializer='normal',activation='relu'))
# Hidden layer-8
mymodel.add(Dense(units=50,
kernel_initializer='normal',activation='relu'))

# output layer
mymodel.add(Dense(units=1,kernel_initializer='normal'))
print(mymodel.summary())
from sklearn.model_selection import KFold
sum_mse=0
sum_r_square=0
kf=KFold(n_splits=5)
for train_index, test_index in kf.split(X_data):
    X_train, X_test = X_data[train_index], X_data[test_index]
    y_train, y_test = y_data[train_index], y_data[test_index]
    # Training our model build above
    mymodel.compile(loss='mean_squared_error', optimizer='adam')
    # Training model
    mymodel.fit(X_train, y_train, batch_size = 32, epochs = 50, verbose=0)
    y_pred=mymodel.predict(X_test)
    # MSE calculation base true output and model output
    mse = mean_squared_error(y_test, y_pred)
    # R-square calculation base true output and model output
    r_squared = r2_score(y_test, y_pred)
    # MSE calculation base true output and model output
    mse = mean_squared_error(y_test, y_pred)
    # R-square calculation base true output and model output
    r_squared = r2_score(y_test, y_pred)
    sum_mse=+mse
    sum_r_square=+r_squared
avg_mse=sum_mse/5
avg_r_squared = sum_r_square /5
print(f'mse = {avg_mse:.2}')
print(f'r_squared = {avg_r_squared:.2%}')
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_45 (Dense)            (None, 50)                100
#
#  dense_46 (Dense)            (None, 50)                2550
#
#  dense_47 (Dense)            (None, 50)                2550
#
#  dense_48 (Dense)            (None, 50)                2550
#
#  dense_49 (Dense)            (None, 50)                2550
#
#  dense_50 (Dense)            (None, 50)                2550
#
#  dense_51 (Dense)            (None, 50)                2550
#
#  dense_52 (Dense)            (None, 50)                2550
#
#  dense_53 (Dense)            (None, 1)                 51
#
# ...
# Total params: 18,001
# Trainable params: 18,001
# Non-trainable params: 0
# _________________________________________________________________
# None
# mse = 1e+01
# r_squared = -2.49%

# %%
#P2
#hidden layer 8 has smallest mse

import numpy as np
import math as mt
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt
import random

x=np.linspace(-2*mt.pi,2*mt.pi,1000)
ya=(np.sin(x))*x**2+2*np.sin(x)
z=np.random.randn(1,1000)
y=ya+z
X_data=np.reshape(x,[1000,1])
y_data=np.reshape(y,[1000,1])
from keras.models import Sequential
from keras.layers import Dense
mymodel = Sequential()
# input and Hidden layer-1 
mymodel.add(Dense(units=50, input_dim=1,
kernel_initializer='normal',activation='relu'))
# Hidden layer-2
mymodel.add(Dense(units=50,
kernel_initializer='normal',activation='relu'))
# Hidden layer-3
mymodel.add(Dense(units=50,
kernel_initializer='normal',activation='relu'))
# Hidden layer-4
mymodel.add(Dense(units=50,
kernel_initializer='normal',activation='relu'))
# Hidden layer-5
mymodel.add(Dense(units=50,
kernel_initializer='normal',activation='relu'))
# Hidden layer-6
mymodel.add(Dense(units=50,
kernel_initializer='normal',activation='relu'))
# Hidden layer-7
mymodel.add(Dense(units=50,
kernel_initializer='normal',activation='relu'))
# Hidden layer-8
mymodel.add(Dense(units=50,
kernel_initializer='normal',activation='relu'))

# output layer
mymodel.add(Dense(units=1,kernel_initializer='normal'))
print(mymodel.summary())
from sklearn.model_selection import KFold
sum_mse=0
sum_r_square=0
kf=KFold(n_splits=5)
for train_index, test_index in kf.split(X_data):
    X_train, X_test = X_data[train_index], X_data[test_index]
    y_train, y_test = y_data[train_index], y_data[test_index]
    # Training our model build above
    mymodel.compile(loss='mean_squared_error', optimizer='adam')
    # Training model
    mymodel.fit(X_train, y_train, batch_size = 32, epochs = 50, verbose=0)
    y_pred=mymodel.predict(X_test)
y_out=mymodel.predict(X_data)
plt.plot(X_data,y_out)
# Out:
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_90 (Dense)            (None, 50)                100
#
#  dense_91 (Dense)            (None, 50)                2550
#
#  dense_92 (Dense)            (None, 50)                2550
#
#  dense_93 (Dense)            (None, 50)                2550
#
#  dense_94 (Dense)            (None, 50)                2550
#
#  dense_95 (Dense)            (None, 50)                2550
#
#  dense_96 (Dense)            (None, 50)                2550
#
#  dense_97 (Dense)            (None, 50)                2550
#
#  dense_98 (Dense)            (None, 1)                 51
#
# ...
# Total params: 18,001
# Trainable params: 18,001
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
import numpy as np
import math as mt
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt
import random

x=np.linspace(-2*mt.pi,2*mt.pi,1000)
ya=(np.sin(x))*x**2+2*np.sin(x)
z=np.random.randn(1,1000)
y=ya+z
X_data=np.reshape(x,[1000,1])
y_data=np.reshape(y,[1000,1])
plt.scatter(X_data,y_data)
#this plot if it is similar to original plot of X_data and y_data

# %%
#P3

import numpy as np
import math as mt
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt
import random

x=np.linspace(-2*mt.pi,2*mt.pi,1000)
ya=(np.sin(x))*x**2+2*np.sin(x)
z=np.random.randn(1,1000)
y=ya+z
X_data=np.reshape(x,[1000,1])
y_data=np.reshape(y,[1000,1])
from keras.models import Sequential
from keras.layers import Dense
mymodel = Sequential()
# input and Hidden layer-1 
mymodel.add(Dense(units=10, input_dim=1,
kernel_initializer='normal',activation='relu'))
# Hidden layer-2
mymodel.add(Dense(units=50,
kernel_initializer='normal',activation='relu'))
# Hidden layer-3
mymodel.add(Dense(units=80,
kernel_initializer='normal',activation='relu'))
# Hidden layer-4
mymodel.add(Dense(units=150,
kernel_initializer='normal',activation='relu'))


# output layer
mymodel.add(Dense(units=1,kernel_initializer='normal'))
print(mymodel.summary())
from sklearn.model_selection import KFold
sum_mse=0
sum_r_square=0
kf=KFold(n_splits=5)
for train_index, test_index in kf.split(X_data):
    X_train, X_test = X_data[train_index], X_data[test_index]
    y_train, y_test = y_data[train_index], y_data[test_index]
    # Training our model build above
    mymodel.compile(loss='mean_squared_error', optimizer='adam')
    # Training model
    mymodel.fit(X_train, y_train, batch_size = 32, epochs = 50, verbose=0)
    y_pred=mymodel.predict(X_test)
    # MSE calculation base true output and model output
    mse = mean_squared_error(y_test, y_pred)
    # R-square calculation base true output and model output
    r_squared = r2_score(y_test, y_pred)
    # MSE calculation base true output and model output
    mse = mean_squared_error(y_test, y_pred)
    # R-square calculation base true output and model output
    r_squared = r2_score(y_test, y_pred)
    sum_mse=+mse
    sum_r_square=+r_squared
avg_mse=sum_mse/5
avg_r_squared = sum_r_square /5
print(f'mse = {avg_mse:.2}')
print(f'r_squared = {avg_r_squared:.2%}')
# Out:
# Model: "sequential_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_99 (Dense)            (None, 10)                20
#
#  dense_100 (Dense)           (None, 50)                550
#
#  dense_101 (Dense)           (None, 80)                4080
#
#  dense_102 (Dense)           (None, 150)               12150
#
#  dense_103 (Dense)           (None, 1)                 151
#
# ...
# Total params: 16,951
# Trainable params: 16,951
# Non-trainable params: 0
# _________________________________________________________________
# None
# mse = 2.9e+01
# r_squared = -43.02%

# %%
import numpy as np
import math as mt
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt
import random

x=np.linspace(-2*mt.pi,2*mt.pi,1000)
ya=(np.sin(x))*x**2+2*np.sin(x)
z=np.random.randn(1,1000)
y=ya+z
X_data=np.reshape(x,[1000,1])
y_data=np.reshape(y,[1000,1])
from keras.models import Sequential
from keras.layers import Dense
mymodel = Sequential()
# input and Hidden layer-1 
mymodel.add(Dense(units=10, input_dim=1,
kernel_initializer='normal',activation='relu'))
# Hidden layer-2
mymodel.add(Dense(units=10,
kernel_initializer='normal',activation='relu'))
# Hidden layer-3
mymodel.add(Dense(units=10,
kernel_initializer='normal',activation='relu'))
# Hidden layer-4
mymodel.add(Dense(units=10,
kernel_initializer='normal',activation='relu'))


# output layer
mymodel.add(Dense(units=1,kernel_initializer='normal'))
print(mymodel.summary())
from sklearn.model_selection import KFold
sum_mse=0
sum_r_square=0
kf=KFold(n_splits=5)
for train_index, test_index in kf.split(X_data):
    X_train, X_test = X_data[train_index], X_data[test_index]
    y_train, y_test = y_data[train_index], y_data[test_index]
    # Training our model build above
    mymodel.compile(loss='mean_squared_error', optimizer='adam')
    # Training model
    mymodel.fit(X_train, y_train, batch_size = 32, epochs = 50, verbose=0)
    y_pred=mymodel.predict(X_test)
    # MSE calculation base true output and model output
    mse = mean_squared_error(y_test, y_pred)
    # R-square calculation base true output and model output
    r_squared = r2_score(y_test, y_pred)
    # MSE calculation base true output and model output
    mse = mean_squared_error(y_test, y_pred)
    # R-square calculation base true output and model output
    r_squared = r2_score(y_test, y_pred)
    sum_mse=+mse
    sum_r_square=+r_squared
avg_mse=sum_mse/5
avg_r_squared = sum_r_square /5
print(f'mse = {avg_mse:.2}')
print(f'r_squared = {avg_r_squared:.2%}')
# Out:
# Model: "sequential_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_104 (Dense)           (None, 10)                20
#
#  dense_105 (Dense)           (None, 10)                110
#
#  dense_106 (Dense)           (None, 10)                110
#
#  dense_107 (Dense)           (None, 10)                110
#
#  dense_108 (Dense)           (None, 1)                 11
#
# ...
# Total params: 361
# Trainable params: 361
# Non-trainable params: 0
# _________________________________________________________________
# None
# mse = 1.5e+01
# r_squared = -12.47%

# %%
import numpy as np
import math as mt
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt
import random

x=np.linspace(-2*mt.pi,2*mt.pi,1000)
ya=(np.sin(x))*x**2+2*np.sin(x)
z=np.random.randn(1,1000)
y=ya+z
X_data=np.reshape(x,[1000,1])
y_data=np.reshape(y,[1000,1])
from keras.models import Sequential
from keras.layers import Dense
mymodel = Sequential()
# input and Hidden layer-1 
mymodel.add(Dense(units=50, input_dim=1,
kernel_initializer='normal',activation='relu'))
# Hidden layer-2
mymodel.add(Dense(units=50,
kernel_initializer='normal',activation='relu'))
# Hidden layer-3
mymodel.add(Dense(units=50,
kernel_initializer='normal',activation='relu'))
# Hidden layer-4
mymodel.add(Dense(units=50,
kernel_initializer='normal',activation='relu'))


# output layer
mymodel.add(Dense(units=1,kernel_initializer='normal'))
print(mymodel.summary())
from sklearn.model_selection import KFold
sum_mse=0
sum_r_square=0
kf=KFold(n_splits=5)
for train_index, test_index in kf.split(X_data):
    X_train, X_test = X_data[train_index], X_data[test_index]
    y_train, y_test = y_data[train_index], y_data[test_index]
    # Training our model build above
    mymodel.compile(loss='mean_squared_error', optimizer='adam')
    # Training model
    mymodel.fit(X_train, y_train, batch_size = 32, epochs = 50, verbose=0)
    y_pred=mymodel.predict(X_test)
    # MSE calculation base true output and model output
    mse = mean_squared_error(y_test, y_pred)
    # R-square calculation base true output and model output
    r_squared = r2_score(y_test, y_pred)
    # MSE calculation base true output and model output
    mse = mean_squared_error(y_test, y_pred)
    # R-square calculation base true output and model output
    r_squared = r2_score(y_test, y_pred)
    sum_mse=+mse
    sum_r_square=+r_squared
avg_mse=sum_mse/5
avg_r_squared = sum_r_square /5
print(f'mse = {avg_mse:.2}')
print(f'r_squared = {avg_r_squared:.2%}')
# Out:
# Model: "sequential_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_109 (Dense)           (None, 50)                100
#
#  dense_110 (Dense)           (None, 50)                2550
#
#  dense_111 (Dense)           (None, 50)                2550
#
#  dense_112 (Dense)           (None, 50)                2550
#
#  dense_113 (Dense)           (None, 1)                 51
#
# ...
# Total params: 7,801
# Trainable params: 7,801
# Non-trainable params: 0
# _________________________________________________________________
# None
# mse = 2.2e+01
# r_squared = -27.53%

# %%
import numpy as np
import math as mt
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt
import random

x=np.linspace(-2*mt.pi,2*mt.pi,1000)
ya=(np.sin(x))*x**2+2*np.sin(x)
z=np.random.randn(1,1000)
y=ya+z
X_data=np.reshape(x,[1000,1])
y_data=np.reshape(y,[1000,1])
from keras.models import Sequential
from keras.layers import Dense
mymodel = Sequential()
# input and Hidden layer-1 
mymodel.add(Dense(units=80, input_dim=1,
kernel_initializer='normal',activation='relu'))
# Hidden layer-2
mymodel.add(Dense(units=80,
kernel_initializer='normal',activation='relu'))
# Hidden layer-3
mymodel.add(Dense(units=80,
kernel_initializer='normal',activation='relu'))
# Hidden layer-4
mymodel.add(Dense(units=80,
kernel_initializer='normal',activation='relu'))


# output layer
mymodel.add(Dense(units=1,kernel_initializer='normal'))
print(mymodel.summary())
from sklearn.model_selection import KFold
sum_mse=0
sum_r_square=0
kf=KFold(n_splits=5)
for train_index, test_index in kf.split(X_data):
    X_train, X_test = X_data[train_index], X_data[test_index]
    y_train, y_test = y_data[train_index], y_data[test_index]
    # Training our model build above
    mymodel.compile(loss='mean_squared_error', optimizer='adam')
    # Training model
    mymodel.fit(X_train, y_train, batch_size = 32, epochs = 50, verbose=0)
    y_pred=mymodel.predict(X_test)
    # MSE calculation base true output and model output
    mse = mean_squared_error(y_test, y_pred)
    # R-square calculation base true output and model output
    r_squared = r2_score(y_test, y_pred)
    # MSE calculation base true output and model output
    mse = mean_squared_error(y_test, y_pred)
    # R-square calculation base true output and model output
    r_squared = r2_score(y_test, y_pred)
    sum_mse=+mse
    sum_r_square=+r_squared
avg_mse=sum_mse/5
avg_r_squared = sum_r_square /5
print(f'mse = {avg_mse:.2}')
print(f'r_squared = {avg_r_squared:.2%}')
# Out:
# Model: "sequential_16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_114 (Dense)           (None, 80)                160
#
#  dense_115 (Dense)           (None, 80)                6480
#
#  dense_116 (Dense)           (None, 80)                6480
#
#  dense_117 (Dense)           (None, 80)                6480
#
#  dense_118 (Dense)           (None, 1)                 81
#
# ...
# Total params: 19,681
# Trainable params: 19,681
# Non-trainable params: 0
# _________________________________________________________________
# None
# mse = 4.2e+01
# r_squared = -70.96%

# %%
import numpy as np
import math as mt
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt
import random

x=np.linspace(-2*mt.pi,2*mt.pi,1000)
ya=(np.sin(x))*x**2+2*np.sin(x)
z=np.random.randn(1,1000)
y=ya+z
X_data=np.reshape(x,[1000,1])
y_data=np.reshape(y,[1000,1])
from keras.models import Sequential
from keras.layers import Dense
mymodel = Sequential()
# input and Hidden layer-1 
mymodel.add(Dense(units=150, input_dim=1,
kernel_initializer='normal',activation='relu'))
# Hidden layer-2
mymodel.add(Dense(units=150,
kernel_initializer='normal',activation='relu'))
# Hidden layer-3
mymodel.add(Dense(units=150,
kernel_initializer='normal',activation='relu'))
# Hidden layer-4
mymodel.add(Dense(units=150,
kernel_initializer='normal',activation='relu'))


# output layer
mymodel.add(Dense(units=1,kernel_initializer='normal'))
print(mymodel.summary())
from sklearn.model_selection import KFold
sum_mse=0
sum_r_square=0
kf=KFold(n_splits=5)
for train_index, test_index in kf.split(X_data):
    X_train, X_test = X_data[train_index], X_data[test_index]
    y_train, y_test = y_data[train_index], y_data[test_index]
    # Training our model build above
    mymodel.compile(loss='mean_squared_error', optimizer='adam')
    # Training model
    mymodel.fit(X_train, y_train, batch_size = 32, epochs = 50, verbose=0)
    y_pred=mymodel.predict(X_test)
    # MSE calculation base true output and model output
    mse = mean_squared_error(y_test, y_pred)
    # R-square calculation base true output and model output
    r_squared = r2_score(y_test, y_pred)
    # MSE calculation base true output and model output
    mse = mean_squared_error(y_test, y_pred)
    # R-square calculation base true output and model output
    r_squared = r2_score(y_test, y_pred)
    sum_mse=+mse
    sum_r_square=+r_squared
avg_mse=sum_mse/5
avg_r_squared = sum_r_square /5
print(f'mse = {avg_mse:.2}')
print(f'r_squared = {avg_r_squared:.2%}')
# Out:
# Model: "sequential_17"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_119 (Dense)           (None, 150)               300
#
#  dense_120 (Dense)           (None, 150)               22650
#
#  dense_121 (Dense)           (None, 150)               22650
#
#  dense_122 (Dense)           (None, 150)               22650
#
#  dense_123 (Dense)           (None, 1)                 151
#
# ...
# Total params: 68,401
# Trainable params: 68,401
# Non-trainable params: 0
# _________________________________________________________________
# None
# mse = 9.2
# r_squared = 0.12%

# %%
#P4

#after P3, 1 layer 10, 2 layer 10, 3 layer 10, 4 layer 10, has minimum mse.
import numpy as np
import math as mt
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt
import random

x=np.linspace(-2*mt.pi,2*mt.pi,1000)
ya=(np.sin(x))*x**2+2*np.sin(x)
z=np.random.randn(1,1000)
y=ya+z
X_data=np.reshape(x,[1000,1])
y_data=np.reshape(y,[1000,1])
from keras.models import Sequential
from keras.layers import Dense
mymodel = Sequential()
# input and Hidden layer-1 
mymodel.add(Dense(units=10, input_dim=1,
kernel_initializer='normal',activation='relu'))
# Hidden layer-2
mymodel.add(Dense(units=10,
kernel_initializer='normal',activation='relu'))
# Hidden layer-3
mymodel.add(Dense(units=10,
kernel_initializer='normal',activation='relu'))
# Hidden layer-4
mymodel.add(Dense(units=10,
kernel_initializer='normal',activation='relu'))


# output layer
mymodel.add(Dense(units=1,kernel_initializer='normal'))
print(mymodel.summary())
from sklearn.model_selection import KFold
sum_mse=0
sum_r_square=0
kf=KFold(n_splits=5)
for train_index, test_index in kf.split(X_data):
    X_train, X_test = X_data[train_index], X_data[test_index]
    y_train, y_test = y_data[train_index], y_data[test_index]
    # Training our model build above
    mymodel.compile(loss='mean_squared_error', optimizer='adam')
    # Training model
    mymodel.fit(X_train, y_train, batch_size = 32, epochs = 50, verbose=0)
    y_pred=mymodel.predict(X_test)
y_out=mymodel.predict(X_data)
plt.plot(X_data,y_out)

#is similar to the original plot
# Out:
# Model: "sequential_18"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_124 (Dense)           (None, 10)                20
#
#  dense_125 (Dense)           (None, 10)                110
#
#  dense_126 (Dense)           (None, 10)                110
#
#  dense_127 (Dense)           (None, 10)                110
#
#  dense_128 (Dense)           (None, 1)                 11
#
# ...
# Total params: 361
# Trainable params: 361
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# P5: Increasing the number of layers have better performance than increasing the number of neuons of each layers( concluded by comparing the r square error as well as the mse)
